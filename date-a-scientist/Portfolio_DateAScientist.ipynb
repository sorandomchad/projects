# %% [markdown]
# <a href="https://colab.research.google.com/github/sorandomchad/projects/blob/main/date-a-scientist/Portfolio_DateAScientist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Portfolio Project: OkCupid Date-A-Scientist
#
# In recent years, there has been a massive rise in the usage of dating apps to find love. Many of these apps use sophisticated data science techniques to recommend possible matches to users and to optimize the user experience. These apps give us access to a wealth of information that we’ve never had before about how different people experience romance.
#
# In this portfolio project, we will analyze some data from OKCupid, an app that focuses on using multiple choice and short answers to match users.
#
# We will also create a presentation about our findings from this OKCupid dataset.
#
# The purpose of this project is to practice formulating questions and implementing machine learning techniques to answer those questions.

# %% [markdown]
# ## The Dataset
#
# The dataset includes about 60k profiles from the OkCupid application in a csv format. Some salient features include age, bio, religion, ethnicity, height, job, location, sex, sexual orientation, astrology sign.

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Load dataset with pandas

# %%
# load data
data = pd.read_csv('profiles.csv')
sample_data = data.sample(n=1000, random_state=42)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Data Cleaning

# %%
sample_data.head()
# Out:
#        age body_type               diet    drinks  drugs  \
# 4800    26   average           anything  socially  never
# 56896   37  athletic                NaN  socially  never
# 17834   30       fit           anything  socially  never
# 27275   26   average    mostly anything  socially    NaN
# 3335    33   average  strictly anything     often    NaN
#
#                                education  \
# 4800          graduated from high school
# 56896                                NaN
# 17834         working on masters program
# 27275  graduated from college/university
# 3335   graduated from college/university
#
#                                                   essay0  \
# 4800   i am really obsessed with music and would love...
# 56896  as for me, im a crazy busy hair stylist by day...
# 17834  i like to look for the humorous side in everyt...
# 27275  i love trees, i'm not crazy about them though<...
# 3335   i come to san francisco by way of new york, wh...
#
#                                                   essay1  \
# 4800   i am supervisor and i am really bored of it. i...
# 56896                   trying to juggle career and life
# 17834  currently going to business school full time, ...
# 27275  12:50 press return<br />\nif you know what tha...
# 3335   i've taken up iaido with a fantastic sensei in...
#
#                                                   essay2  \
# 4800   guitar i like to think i am alright. i am alwa...
# 56896                                                NaN
# 17834  writing, telling stories, laughing at myself, ...
# 27275  different things, different times. but general...
# 3335   observing myself and others. sticking with it ...
#
#                                                   essay3  ...  \
# 4800   well used to be my hair. had to get rid of the...  ...
# 56896                      i suppose you could ask them.  ...
# 17834  people tell me i'm sarcastic, funny (hilarious...  ...
# 27275  i look way too innocent, clueless or oblivious...  ...
# 3335   beats me! nobody has ever told me, and i've ne...  ...
#
#                         location                offspring orientation  \
# 4800        martinez, california                      NaN    straight
# 56896  san francisco, california                      NaN         gay
# 17834  san francisco, california  doesn&rsquo;t have kids    straight
# 27275       berkeley, california                      NaN    straight
# 3335   san francisco, california  doesn&rsquo;t have kids    straight
#
#                             pets                       religion sex  \
# 4800                         NaN                            NaN   m
# 56896                 likes dogs                            NaN   m
# 17834  likes dogs and likes cats  atheism and laughing about it   m
# 27275                 likes dogs    other and laughing about it   m
# 3335                  likes cats                        atheism   m
#
#                                            sign  smokes  \
# 4800                                sagittarius      no
# 56896   libra and it&rsquo;s fun to think about      no
# 17834  gemini and it&rsquo;s fun to think about      no
# 27275  gemini and it&rsquo;s fun to think about     yes
# 3335                                        NaN      no
#
#                                                   speaks  status
# 4800                                             english  single
# 56896                                            english  single
# 17834  english (fluently), chinese (fluently), spanis...  single
# 27275                                   english, persian  single
# 3335                          english, japanese (poorly)  single
#
# [5 rows x 31 columns]

# %%
sample_data.essay0.iloc[11]
# Out:
# "its always hard to write about this sort of stuff...but here's a\nshot:<br />\nalways up for an adventure on a whim. the worst has been when i\ndrove 5 hours to get lunch...but it was quite worth it.<br />\ni have eclectic hobbies to say the least.<br />\ntry to spend time as much time as possible outside enjoying what\nthe bay area has to offer.<br />\ntravelling to places that have rich per-biblical history...it is\nincredibly fascinating. next trip will either be to greece or\nitaly.<br />\nlove animals...growing up my house resembled more a zoo with\nrabbits, doves, pigeons, baters, cats, dogs and a deer.<br />\nnot too into watching sports...would much rather prefer to get off\nthe couch and do something...though every now and then will watch\nsome f-1.<br />\ni haven't owned a tv since 2003.<br />\nnot the biggest fan of the east coast winters...they're great to\nvisit...but when driving became more a scene for a roller derby\nrink, i had to reconsider my choices...hence the move to sf."

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 4800 to 29995
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          1000 non-null   int64
#  1   body_type    918 non-null    object
#  2   diet         608 non-null    object
#  3   drinks       957 non-null    object
#  4   drugs        768 non-null    object
#  5   education    880 non-null    object
#  6   essay0       913 non-null    object
#  7   essay1       883 non-null    object
#  8   essay2       841 non-null    object
#  9   essay3       825 non-null    object
#  10  essay4       839 non-null    object
#  11  essay5       816 non-null    object
#  12  essay6       753 non-null    object
#  13  essay7       790 non-null    object
#  14  essay8       697 non-null    object
#  15  essay9       795 non-null    object
#  16  ethnicity    900 non-null    object
#  17  height       1000 non-null   float64
#  18  income       1000 non-null   int64
#  19  job          860 non-null    object
#  20  last_online  1000 non-null   object
#  21  location     1000 non-null   object
#  22  offspring    389 non-null    object
#  23  orientation  1000 non-null   object
#  24  pets         647 non-null    object
#  25  religion     655 non-null    object
#  26  sex          1000 non-null   object
#  27  sign         817 non-null    object
#  28  smokes       908 non-null    object
#  29  speaks       999 non-null    object
#  30  status       1000 non-null   object
# dtypes: float64(1), int64(2), object(28)
# memory usage: 250.0+ KB

# %% [markdown]
# The `last_online` column will be dropped because of bad formatting and irrelevance to our analysis.

# %%
# drop last_online column
if 'last_online' in sample_data.columns:
  sample_data = sample_data.drop(columns=['last_online'])
sample_data.columns
# Out:
# Index(['age', 'body_type', 'diet', 'drinks', 'drugs', 'education', 'essay0',
#        'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7',
#        'essay8', 'essay9', 'ethnicity', 'height', 'income', 'job', 'location',
#        'offspring', 'orientation', 'pets', 'religion', 'sex', 'sign', 'smokes',
#        'speaks', 'status'],
#       dtype='object')

# %%
sample_data.isnull().sum()/len(sample_data)
# Out:
# age            0.000
# body_type      0.082
# diet           0.392
# drinks         0.043
# drugs          0.232
# education      0.120
# essay0         0.087
# essay1         0.117
# essay2         0.159
# essay3         0.175
# essay4         0.161
# essay5         0.184
# essay6         0.247
# essay7         0.210
# essay8         0.303
# essay9         0.205
# ethnicity      0.100
# height         0.000
# income         0.000
# job            0.140
# location       0.000
# offspring      0.611
# orientation    0.000
# pets           0.353
# religion       0.345
# sex            0.000
# sign           0.183
# smokes         0.092
# speaks         0.001
# status         0.000
# dtype: float64

# %%
# !pip install contractions
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.10/dist-packages (0.1.73)
# Requirement already satisfied: textsearch>=0.0.21 in /usr/local/lib/python3.10/dist-packages (from contractions) (0.0.24)
# Requirement already satisfied: anyascii in /usr/local/lib/python3.10/dist-packages (from textsearch>=0.0.21->contractions) (0.3.2)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.10/dist-packages (from textsearch>=0.0.21->contractions) (2.1.0)

# %% [markdown]
# ## Text preprocessing

# %%
# libraries for formatting text
import contractions
import re
import string

# %% [markdown]
# ### Contractions

# %% [markdown]
# We begin cleaning the text data in the essay columns by separating contractions. Contractions are abbreviations of two words separated by an apostrophe. With the `contractions` module, we can separate contractions which reduces the dimensionality of the document-term matrix in analysis.
#
# The ASCII equivalent of the apostrophe is `&rsquo;`, which we will replace. Then, the `contractions.fix()` function fully expands the contractions in the dataset.

# %% [markdown]
# ### Punctuation
# Other than standard punctuation, we need to get rid of:
# * the newline character `\n`
# * the xhtml tags `<(any number of chars)>`
#
# The `string.punctuation` list in python contains the following punctuation symbols:
#
# ``!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~``

# %%
def remove_punctuation(text):
  '''
    Accepts a string as input and returns a cleaned string without punctuation.
  '''
  # replace &rsquo; with '
  text = re.sub(r'&rsquo;', '\'', text)

  # expand contractions
  text = contractions.fix(text)

  # remove newlines, html tags, forward slashes, and ellipses
  text = re.sub(r'\n|<[^>]+>|\.{3}|/', ' ', text)

  # remove remaining punctuation
  PUNCT_TO_REMOVE = string.punctuation
  text = text.translate(str.maketrans('', '',
                                    PUNCT_TO_REMOVE))

  # remove extra space
  text = re.sub(r'\s{2,}', ' ', text)

  return text

# %% [markdown]
# Gather all of the text columns.

# %%
# all of the text columns in the dataframe
text_cols = [col for col in sample_data.columns if sample_data[col].dtype == 'object']
text_cols
# Out:
# ['body_type',
#  'diet',
#  'drinks',
#  'drugs',
#  'education',
#  'essay0',
#  'essay1',
#  'essay2',
#  'essay3',
#  'essay4',
#  'essay5',
#  'essay6',
#  'essay7',
#  'essay8',
#  'essay9',
#  'ethnicity',
#  'job',
#  'location',
#  'offspring',
#  'orientation',
#  'pets',
#  'religion',
#  'sex',
#  'sign',
#  'smokes',
#  'speaks',
#  'status']

# %% [markdown]
# Since `NaN` is a numeric type, we can use the empty string as an equivalent so that we can use string operations on the data.
#
# The `.map()` method applies a function to a DataFrame elementwise. Here, we will combine this method with the `remove_punctuation()` function to get rid of punctuation, leaving only words in the text columns.

# %%
# change NaNs to empty strings to avoid problems with string operations
sample_data[text_cols] = sample_data[text_cols].fillna('')

# remove punctuation of text in the dataset
sample_data[text_cols] = sample_data[text_cols].map(remove_punctuation)
sample_data[text_cols].head()
# Out:
#       body_type               diet    drinks  drugs  \
# 4800    average           anything  socially  never
# 56896  athletic                     socially  never
# 17834       fit           anything  socially  never
# 27275   average    mostly anything  socially
# 3335    average  strictly anything     often
#
#                                education  \
# 4800          graduated from high school
# 56896
# 17834         working on masters program
# 27275  graduated from college university
# 3335   graduated from college university
#
#                                                   essay0  \
# 4800   i am really obsessed with music and would love...
# 56896  as for me i am a crazy busy hair stylist by da...
# 17834  i like to look for the humorous side in everyt...
# 27275  i love trees i am not crazy about them though ...
# 3335   i come to san francisco by way of new york whe...
#
#                                                   essay1  \
# 4800   i am supervisor and i am really bored of it i ...
# 56896                   trying to juggle career and life
# 17834  currently going to business school full time a...
# 27275  1250 press return if you know what that is you...
# 3335   i have taken up iaido with a fantastic sensei ...
#
#                                                   essay2  \
# 4800   guitar i like to think i am alright i am alway...
# 56896
# 17834  writing telling stories laughing at myself hel...
# 27275  different things different times but generally...
# 3335   observing myself and others sticking with it t...
#
#                                                   essay3  \
# 4800   well used to be my hair had to get rid of the ...
# 56896                       i suppose you could ask them
# 17834  people tell me i am sarcastic funny hilarious ...
# 27275  i look way too innocent clueless or oblivious ...
# 3335   beats me nobody has ever told me and i have ne...
#
#                                                   essay4  ...  \
# 4800   to many movies to just pick one and same with ...  ...
# 56896                                                     ...
# 17834  movies office space fight club i love situatio...  ...
# 27275  db tool in flames lately a lot of postrock god...  ...
# 3335   books i have been on a nonfiction history kick...  ...
#
#                        location           offspring orientation  \
# 4800        martinez california                        straight
# 56896  san francisco california                             gay
# 17834  san francisco california  does not have kids    straight
# 27275       berkeley california                        straight
# 3335   san francisco california  does not have kids    straight
#
#                             pets                       religion sex  \
# 4800                                                              m
# 56896                 likes dogs                                  m
# 17834  likes dogs and likes cats  atheism and laughing about it   m
# 27275                 likes dogs    other and laughing about it   m
# 3335                  likes cats                        atheism   m
#
#                                       sign smokes  \
# 4800                           sagittarius     no
# 56896   libra and it is fun to think about     no
# 17834  gemini and it is fun to think about     no
# 27275  gemini and it is fun to think about    yes
# 3335                                           no
#
#                                                speaks  status
# 4800                                          english  single
# 56896                                         english  single
# 17834  english fluently chinese fluently spanish okay  single
# 27275                                 english persian  single
# 3335                          english japanese poorly  single
#
# [5 rows x 27 columns]

# %%
import re

text = """meine amerikane brille.<br />
<br />
whatever i'm doing, i'm <a class="ilink" href=
"/interests?i=into+it">into it</a>. my <a class="ilink" href=
"/interests?i=intensity">intensity</a> is usually a boon.
(usually.) also, they often notice that i'm tall. which is weird,
because i'm really, really not."""

# Replace "cats" or "dogs" with "animals"
new_text = re.sub(r"<[^>]+>", "<UNK>", text)

new_text
# Out:
# "meine amerikane brille.<UNK>\n<UNK>\nwhatever i'm doing, i'm <UNK>into it<UNK>. my <UNK>intensity<UNK> is usually a boon.\n(usually.) also, they often notice that i'm tall. which is weird,\nbecause i'm really, really not."

# %% [markdown]
# ### Removing stopwords
#
# Stopwords are commonly occurring words in a language like 'the', 'to', 'at'. They usually do not enhance understanding of a text and we can get rid of them in most cases.

# %%
# library
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize     # to break down text into tokens

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
STOPWORDS = set(stopwords.words('english'))   # list of stopwords

# function to remove stopwords
def remove_stopwords(text):
    """custom function to remove the stopwords"""
    return " ".join([word for word in word_tokenize(text) if word not in STOPWORDS])

# %%
# cols = ['body_type',
#  'diet',
#  'drinks',
#  'drugs',
#  'education',
#  'ethnicity',
#  'job',
#  'orientation',
#  'pets',
#  'religion',
#  'sign',
#  'smokes',
#  'speaks',
#  'status']
# # removing stopwords
# sample_data[cols] = sample_data[cols].map(remove_stopwords)
# sample_data[text_cols].head()

# %% [markdown]
# ## Cleaning Numeric Columns

# %%
# all of the numeric columns in the dataframe
numeric_cols = [col for col in sample_data.columns if sample_data[col].dtype != 'object']
numeric_cols
# Out:
# ['age', 'height', 'income']

# %%
sample_data[numeric_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 4800 to 29995
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     1000 non-null   int64
#  1   height  1000 non-null   float64
#  2   income  1000 non-null   int64
# dtypes: float64(1), int64(2)
# memory usage: 31.2 KB

# %%
# null numeric columns
sample_data[numeric_cols].isnull().sum()
# Out:
# age       0
# height    0
# income    0
# dtype: int64

# %% [markdown]
# ### Disguised null values
# Though the `income` column has no `NaN`s, the dataset uses the sentinel value of -1 to indicate a null value. We will replace them with `NaN`.

# %%
# replace -1 with NaN
sample_data.income = sample_data['income'].where(sample_data.income != -1, np.nan)

# %%
# recheck for nulls
sample_data[numeric_cols].isnull().sum()/len(sample_data)
# Out:
# age       0.000
# height    0.000
# income    0.831
# dtype: float64

# %% [markdown]
# 83 percent the `income` column is missing, therefore using that variable in any analysis could introduce bias in our dataset. We will drop it from the dataset.

# %%
# dropping the income column
sample_data.drop(columns=['income'])
numeric_cols.remove('income')
numeric_cols
# Out:
# ['age', 'height']

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# In this section, we will explore some summary statistics of the `age` and `height` variables.

# %%
sample_data[numeric_cols].describe()
# Out:
#                age       height
# count  1000.000000  1000.000000
# mean     32.210000    68.390000
# std       9.118939     3.836485
# min      18.000000    58.000000
# 25%      26.000000    66.000000
# 50%      30.000000    68.000000
# 75%      37.000000    71.000000
# max      69.000000    81.000000

# %% [markdown]
# * Mean height: 5'8.39"
# * Max height: 6'9"
# * Min height: 4'10"

# %%
# unique values in text columns
sample_data[text_cols].nunique()
# Out:
# body_type       13
# diet            14
# drinks           7
# drugs            4
# education       29
# essay0         914
# essay1         882
# essay2         839
# essay3         788
# essay4         839
# essay5         817
# essay6         744
# essay7         782
# essay8         694
# essay9         784
# ethnicity       50
# job             22
# location        51
# offspring       14
# orientation      3
# pets            16
# religion        41
# sex              2
# sign            48
# smokes           6
# speaks         301
# status           4
# dtype: int64

# %%
# inspecting the unique categories of some of the variables
for var in text_cols:
  if sample_data[sample_data[var] != ''][var].nunique() < 70:
    print(f"{var} categories:", sample_data[var].unique())
    print("\n\n")
# Out:
# body_type categories: ['average' 'athletic' 'fit' 'a little extra' 'curvy' 'thin' 'skinny' ''
#  'used up' 'full figured' 'overweight' 'rather not say' 'jacked']
#
#
#
# diet categories: ['anything' '' 'mostly anything' 'strictly anything' 'mostly vegetarian'
#  'vegetarian' 'mostly other' 'strictly vegetarian' 'vegan'
#  'strictly other' 'mostly vegan' 'other' 'mostly kosher' 'strictly vegan']
#
#
#
# drinks categories: ['socially' 'often' 'not at all' 'rarely' '' 'very often' 'desperately']
#
#
#
# drugs categories: ['never' '' 'sometimes' 'often']
#
#
#
# education categories: ['graduated from high school' '' 'working on masters program'
#  'graduated from college university' 'graduated from masters program'
#  'working on law school' 'graduated from space camp'
#  'graduated from twoyear college' 'graduated from law school'
#  'working on college university' 'dropped out of college university'
#  'working on med school' 'high school' 'working on space camp'
#  'graduated from phd program' 'dropped out of twoyear college'
#  'college university' 'working on twoyear college'
#  'working on phd program' 'dropped out of high school'
#  'dropped out of space camp' 'twoyear college' 'graduated from med school'
#  'space camp' 'working on high school' 'masters program'
#  'dropped out of law school' 'dropped out of phd program'
#  'dropped out of masters program']
#
#
#
# ethnicity categories: ['white' 'asian' 'middle eastern other' 'other' '' 'indian'
#  'hispanic latin' 'asian pacific islander other'
#  'asian middle eastern indian other' 'black' 'asian white'
#  'hispanic latin white' 'black indian hispanic latin'
#  'asian middle eastern' 'asian middle eastern other' 'white other'
#  'black other' 'black white' 'hispanic latin other' 'pacific islander'
#  'hispanic latin white other' 'indian hispanic latin' 'asian indian'
#  'middle eastern indian' 'middle eastern' 'middle eastern white'
#  'pacific islander white' 'asian white other'
#  'native american hispanic latin white' 'asian hispanic latin'
#  'black white other' 'asian native american other'
#  'middle eastern hispanic latin' 'middle eastern white other'
#  'asian pacific islander' 'native american white' 'asian other'
#  'pacific islander other' 'asian black native american white'
#  'native american hispanic latin white other' 'indian white other'
#  'black hispanic latin' 'indian pacific islander'
#  'pacific islander hispanic latin' 'asian native american white'
#  'native american' 'asian black white' 'black hispanic latin white'
#  'asian black native american'
#  'black native american hispanic latin white']
#
#
#
# job categories: ['other' 'science tech engineering' 'computer hardware software'
#  'entertainment media' 'medicine health' 'education academia'
#  'law legal services' 'banking financial real estate'
#  'artistic musical writer' 'sales marketing biz dev' 'student' ''
#  'retired' 'executive management' 'unemployed' 'hospitality travel'
#  'transportation' 'construction craftsmanship' 'political government'
#  'rather not say' 'clerical administrative' 'military']
#
#
#
# location categories: ['martinez california' 'san francisco california' 'berkeley california'
#  'walnut creek california' 'stanford california' 'san anselmo california'
#  'oakland california' 'palo alto california' 'pleasant hill california'
#  'south san francisco california' 'san rafael california'
#  'hayward california' 'redwood city california' 'albany california'
#  'belmont california' 'novato california' 'daly city california'
#  'san bruno california' 'mountain view california' 'san mateo california'
#  'benicia california' 'burlingame california' 'sausalito california'
#  'el cerrito california' 'emeryville california' 'san leandro california'
#  'alameda california' 'richmond california' 'vallejo california'
#  'larkspur california' 'millbrae california' 'green brae california'
#  'rodeo california' 'mill valley california' 'muir beach california'
#  'menlo park california' 'lagunitas california' 'moraga california'
#  'san carlos california' 'san pablo california' 'los angeles california'
#  'el sobrante california' 'san lorenzo california' 'crockett california'
#  'montara california' 'castro valley california'
#  'half moon bay california' 'lafayette california' 'pinole california'
#  'woodacre california' 'los gatos california']
#
#
#
# offspring categories: ['' 'does not have kids' 'does not have kids but wants them'
#  'does not have kids and does not want any'
#  'does not have kids but might want them' 'does not want kids' 'has a kid'
#  'wants kids' 'has a kid but does not want more' 'might want kids'
#  'has kids' 'has a kid and might want more'
#  'has kids but does not want more' 'has kids and might want more']
#
#
#
# orientation categories: ['straight' 'gay' 'bisexual']
#
#
#
# pets categories: ['' 'likes dogs' 'likes dogs and likes cats' 'likes cats'
#  'likes dogs and has cats' 'has dogs' 'has dogs and dislikes cats'
#  'has dogs and likes cats' 'has dogs and has cats'
#  'likes dogs and dislikes cats' 'has cats'
#  'dislikes dogs and dislikes cats' 'dislikes dogs and likes cats'
#  'dislikes cats' 'dislikes dogs and has cats' 'dislikes dogs']
#
#
#
# religion categories: ['' 'atheism and laughing about it' 'other and laughing about it'
#  'atheism' 'catholicism' 'buddhism' 'catholicism and laughing about it'
#  'agnosticism and very serious about it'
#  'catholicism but not too serious about it'
#  'christianity but not too serious about it'
#  'agnosticism but not too serious about it'
#  'judaism and somewhat serious about it'
#  'atheism but not too serious about it' 'agnosticism'
#  'atheism and somewhat serious about it' 'other'
#  'agnosticism and laughing about it'
#  'catholicism and somewhat serious about it'
#  'christianity and very serious about it'
#  'atheism and very serious about it' 'other and somewhat serious about it'
#  'christianity and somewhat serious about it'
#  'christianity and laughing about it'
#  'agnosticism and somewhat serious about it'
#  'judaism but not too serious about it' 'christianity'
#  'buddhism but not too serious about it'
#  'other but not too serious about it' 'buddhism and laughing about it'
#  'hinduism and somewhat serious about it'
#  'hinduism but not too serious about it' 'other and very serious about it'
#  'islam and laughing about it' 'judaism'
#  'buddhism and somewhat serious about it' 'judaism and laughing about it'
#  'buddhism and very serious about it'
#  'catholicism and very serious about it' 'islam'
#  'islam but not too serious about it' 'hinduism']
#
#
#
# sex categories: ['m' 'f']
#
#
#
# sign categories: ['sagittarius' 'libra and it is fun to think about'
#  'gemini and it is fun to think about' '' 'leo'
#  'sagittarius but it does not matter' 'aquarius but it does not matter'
#  'cancer and it is fun to think about' 'taurus but it does not matter'
#  'capricorn but it does not matter' 'cancer'
#  'taurus and it is fun to think about'
#  'aquarius and it is fun to think about' 'leo but it does not matter'
#  'virgo' 'aries but it does not matter'
#  'aries and it is fun to think about' 'virgo and it is fun to think about'
#  'cancer but it does not matter' 'scorpio' 'pisces but it does not matter'
#  'pisces and it matters a lot' 'scorpio and it is fun to think about'
#  'virgo but it does not matter' 'sagittarius and it is fun to think about'
#  'libra' 'capricorn and it is fun to think about' 'aquarius'
#  'aries and it matters a lot' 'libra but it does not matter'
#  'leo and it is fun to think about' 'gemini' 'virgo and it matters a lot'
#  'capricorn' 'pisces and it is fun to think about'
#  'cancer and it matters a lot' 'gemini but it does not matter' 'taurus'
#  'scorpio but it does not matter' 'aries' 'pisces'
#  'scorpio and it matters a lot' 'capricorn and it matters a lot'
#  'leo and it matters a lot' 'aquarius and it matters a lot'
#  'libra and it matters a lot' 'taurus and it matters a lot'
#  'sagittarius and it matters a lot']
#
#
#
# smokes categories: ['no' 'yes' 'when drinking' 'trying to quit' '' 'sometimes']
#
#
#
# status categories: ['single' 'available' 'seeing someone' 'married']

# %% [markdown]
# ### Religion and Sign
# For the purpose of simplicity, the first word in the column will be used to assign each person a value for these variables.

# %%
# restricting categories to the first word in the entry
sample_data[['religion', 'sign']] = sample_data[['religion', 'sign']].map(lambda text: text.split()[0] if text != '' else '')

# %%
# checking for correctness
print(sample_data['religion'].unique())
print('\n')
print(sample_data['sign'].unique())
# Out:
# ['' 'atheism' 'other' 'catholicism' 'buddhism' 'agnosticism'
#  'christianity' 'judaism' 'hinduism' 'islam']
#
#
# ['sagittarius' 'libra' 'gemini' '' 'leo' 'aquarius' 'cancer' 'taurus'
#  'capricorn' 'virgo' 'aries' 'scorpio' 'pisces']

# %% [markdown]
# ### Location
# Since all respondents are for CA, we will try

# %%
sample_data['location'] = sample_data['location'].map(lambda text: ' '.join(text.split()[:-1]) if text != '' else '')

# %%
# checking for correctness
print(sample_data['location'].unique())
# Out:
# ['martinez' 'san francisco' 'berkeley' 'walnut creek' 'stanford'
#  'san anselmo' 'oakland' 'palo alto' 'pleasant hill' 'south san francisco'
#  'san rafael' 'hayward' 'redwood city' 'albany' 'belmont' 'novato'
#  'daly city' 'san bruno' 'mountain view' 'san mateo' 'benicia'
#  'burlingame' 'sausalito' 'el cerrito' 'emeryville' 'san leandro'
#  'alameda' 'richmond' 'vallejo' 'larkspur' 'millbrae' 'green brae' 'rodeo'
#  'mill valley' 'muir beach' 'menlo park' 'lagunitas' 'moraga' 'san carlos'
#  'san pablo' 'los angeles' 'el sobrante' 'san lorenzo' 'crockett'
#  'montara' 'castro valley' 'half moon bay' 'lafayette' 'pinole' 'woodacre'
#  'los gatos']

# %%
# sample_data.to_csv("results.csv", index=False)
